# %%
import pandas as pd

data = pd.read_csv('ObesityDataSet_raw_and_data_sinthetic.csv')

# %%
data.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %% [markdown]
# Sanity Checks

# %%
data['NObeyesdad'].value_counts()
# Out:
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_I     290
# Overweight_Level_II    290
# Normal_Weight          287
# Insufficient_Weight    272
# Name: NObeyesdad, dtype: int64

# %%
data['SMOKE'].value_counts()
# Out:
# no     2067
# yes      44
# Name: SMOKE, dtype: int64

# %%
data.isna().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
data.shape
# Out:
# (2111, 17)

# %%
data.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
data.select_dtypes('object').columns
# Out:
# Index(['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE',
#        'SCC', 'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
data.MTRANS.value_counts()
# Out:
# Public_Transportation    1580
# Automobile                457
# Walking                    56
# Motorbike                  11
# Bike                        7
# Name: MTRANS, dtype: int64

# %%
cleanup_nums = {"Gender":{'Male':1,"Female":2},
                "family_history_with_overweight":{"yes":1,"no":2},
                "FAVC":{"yes":1,"no":2},
                "CAEC":{"Sometimes":1,"Frequently":2,"Always":3,"no":4},
                "SMOKE":{"yes":1,"no":2},
                "SCC":{"yes":1,"no":2},
                "CALC":{"Sometimes":1,"Frequently":2,"Always":3,"no":4},
                "MTRANS":{"Public_Transportation":1,"Automobile":2,"Walking":3,"Motorbike":4,"Bike":5},
                "NObeyesdad": {'Obesity_Type_I':1,
                                'Obesity_Type_III':1,
                                'Obesity_Type_II':1,
                                'Overweight_Level_I':0,
                                'Overweight_Level_II':0,
                                'Normal_Weight':0,
                                'Insufficient_Weight':0}}

# %%
data.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %% [markdown]
# **Definitions of some abbreviated columns:**
#
# Frequent consumption of high caloric food (FAVC)<br>
# Frequency of consumption of vegetables (FCVC)<br>
# Number of main meals (NCP)<br>
# Consumption of food between meals (CAEC)<br>
# Consumption of water daily (CH20)<br>
# Consumption of alcohol (CALC)<br>
# Calories consumption monitoring (SCC)<br>
# Physical activity frequency (FAF)<br>
# Time using technology devices (TUE)<br>
# Transportation used (MTRANS)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.title("family_history_with_overweight")
sns.countplot(data = data,x='family_history_with_overweight')
plt.show()

# %%
data['FAVC'].value_counts()
import seaborn as sns
plt.title("FAVC")
sns.countplot(data = data,x='family_history_with_overweight')
plt.show()

# %%
data['CAEC'].value_counts()
import seaborn as sns
plt.title("FAVC")
sns.countplot(data = data,x='family_history_with_overweight')
# Out:
# <Axes: title={'center': 'FAVC'}, xlabel='family_history_with_overweight', ylabel='count'>

# %%
data['SMOKE'].value_counts()
import seaborn as sns

sns.countplot(data = data,x='family_history_with_overweight')
# Out:
# <Axes: xlabel='family_history_with_overweight', ylabel='count'>

# %%
import seaborn as sns
plt.title("SCC")
sns.countplot(data = data,x='SCC')
# Out:
# <Axes: title={'center': 'SCC'}, xlabel='SCC', ylabel='count'>

# %%
data['CALC'].value_counts()
import seaborn as sns
plt.title("CALC")
sns.countplot(data = data,x='CALC')
plt.show()

# %%
data['MTRANS'].value_counts()
import seaborn as sns
plt.title("MTRANS")
sns.countplot(data = data,x='MTRANS')
plt.xticks(rotation=90)
plt.show()

# %%
data['NObeyesdad'].value_counts()
# Out:
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_I     290
# Overweight_Level_II    290
# Normal_Weight          287
# Insufficient_Weight    272
# Name: NObeyesdad, dtype: int64

# %%
'''
def rep(x):
  if x=='Overweight_Level_I' or x=='Overweight_Level_II':
    return 'Overweight'
  if x=='Normal_Weight':
    return 'Normal_Weight'
  if x=='Insufficient_Weight':
    return 'Insufficient_Weight'
  return 'Obesity'
data['NObeyesdad']=data['NObeyesdad'].apply(lambda x: rep(x))'''
# Out:
# "\ndef rep(x):\n  if x=='Overweight_Level_I' or x=='Overweight_Level_II':\n    return 'Overweight'\n  if x=='Normal_Weight':\n    return 'Normal_Weight'\n  if x=='Insufficient_Weight':\n    return 'Insufficient_Weight'\n  return 'Obesity'\ndata['NObeyesdad']=data['NObeyesdad'].apply(lambda x: rep(x))"

# %%
'''
data['NObeyesdad'].value_counts()
import seaborn as sns

sns.countplot(data = data,x='NObeyesdad')'''
# Out:
# "\ndata['NObeyesdad'].value_counts()\nimport seaborn as sns\n\nsns.countplot(data = data,x='NObeyesdad')"

# %%
data['Gender'].value_counts()
import seaborn as sns
plt.title('Gender')
sns.countplot(data = data,x='Gender')
plt.show()

# %%
plt.title("Age")
sns.histplot(data=data,x='Age')
plt.show()

# %%
plt.title('Height')
sns.histplot(data=data,x='Height')
plt.show()

# %%
plt.title("Weight")
sns.histplot(data=data,x='Weight')
plt.show()

# %%
sns.histplot(data=data,x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
plt.title("Age")
sns.boxplot(data=data, x='Age')
plt.show()

# %%
plt.title("Height")
sns.boxplot(data=data, x='Height')
plt.show()

# %%
plt.title("Weight")
sns.boxplot(data=data, x='Weight')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.title("family_history_with_overweight vs Obesity")
sns.countplot(x='NObeyesdad', hue='family_history_with_overweight', data=data)
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(data=data, x='Age', y='Weight')
plt.title('Scatter Plot: Age vs. Weight')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(data=data, x='Height', y='Weight')
plt.title('Scatter Plot: Height vs. Weight')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
continuous_vars = ['Age', 'Height', 'Weight']
sns.pairplot(data[continuous_vars])
plt.suptitle('Pair Plot for Continuous Variables', y=1.02)
plt.show()

# %%
'''
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in data.drop('NObeyesdad',axis=1).select_dtypes('object'):
  data[col]=le.fit_transform(data[col])
'''
# Out:
# "\nfrom sklearn.preprocessing import LabelEncoder\nle = LabelEncoder()\nfor col in data.drop('NObeyesdad',axis=1).select_dtypes('object'):\n  data[col]=le.fit_transform(data[col])\n"

# %%
data
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
'''
data['SMOKE'] = pd.to_numeric(data['SMOKE'], errors='coerce')
data['NObeyesdad'] = pd.to_numeric(data['NObeyesdad'], errors='coerce')'''
# Out:
# "\ndata['SMOKE'] = pd.to_numeric(data['SMOKE'], errors='coerce')\ndata['NObeyesdad'] = pd.to_numeric(data['NObeyesdad'], errors='coerce')"

# %%
'''
cleanup_nums = {"NObeyesdad": {'Obesity_Type_I':1,
                                'Obesity_Type_III':1,
                                'Obesity_Type_II':1,
                                'Overweight_Level_I':0,
                                'Overweight_Level_II':0,
                                'Normal_Weight':0,
                                'Insufficient_Weight':0}}'''
# Out:
# '\ncleanup_nums = {"NObeyesdad": {\'Obesity_Type_I\':1,\n                                \'Obesity_Type_III\':1,\n                                \'Obesity_Type_II\':1,\n                                \'Overweight_Level_I\':0,\n                                \'Overweight_Level_II\':0,\n                                \'Normal_Weight\':0,\n                                \'Insufficient_Weight\':0}}'

# %%
data = data.replace(cleanup_nums)

# %%
data['NObeyesdad'].value_counts()
# Out:
# 0    1139
# 1     972
# Name: NObeyesdad, dtype: int64

# %%
data
# Out:
#       Gender        Age    Height      Weight  family_history_with_overweight  \
# 0          2  21.000000  1.620000   64.000000                               1
# 1          2  21.000000  1.520000   56.000000                               1
# 2          1  23.000000  1.800000   77.000000                               1
# 3          1  27.000000  1.800000   87.000000                               2
# 4          1  22.000000  1.780000   89.800000                               2
# ...      ...        ...       ...         ...                             ...
# 2106       2  20.976842  1.710730  131.408528                               1
# 2107       2  21.982942  1.748584  133.742943                               1
# 2108       2  22.524036  1.752206  133.689352                               1
# 2109       2  24.361936  1.739450  133.346641                               1
# 2110       2  23.664709  1.738836  133.472641                               1
#
# ...

# %%
data
# Out:
#       Gender        Age    Height      Weight  family_history_with_overweight  \
# 0          2  21.000000  1.620000   64.000000                               1
# 1          2  21.000000  1.520000   56.000000                               1
# 2          1  23.000000  1.800000   77.000000                               1
# 3          1  27.000000  1.800000   87.000000                               2
# 4          1  22.000000  1.780000   89.800000                               2
# ...      ...        ...       ...         ...                             ...
# 2106       2  20.976842  1.710730  131.408528                               1
# 2107       2  21.982942  1.748584  133.742943                               1
# 2108       2  22.524036  1.752206  133.689352                               1
# 2109       2  24.361936  1.739450  133.346641                               1
# 2110       2  23.664709  1.738836  133.472641                               1
#
# ...

# %%
type(data['SMOKE'])
# Out:
# pandas.core.series.Series

# %%
import statsmodels.api as sm
model = sm.Logit(endog=data['NObeyesdad'],exog=data['SMOKE']).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.689965
#          Iterations 3

# %%
print(model.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:             NObeyesdad   No. Observations:                 2111
# Model:                          Logit   Df Residuals:                     2110
# Method:                           MLE   Df Model:                            0
# Date:                Mon, 04 Dec 2023   Pseudo R-squ.:               7.223e-05
# Time:                        21:49:17   Log-Likelihood:                -1456.5
# converged:                       True   LL-Null:                       -1456.6
# Covariance Type:            nonrobust   LLR p-value:                       nan
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# SMOKE         -0.0805      0.022     -3.660      0.000      -0.124      -0.037
# ...

# %%
data = data.replace({'family_history_with_overweight':{'yes':1,'no':0}})
import statsmodels.api as sm
model = sm.Logit(endog=data['NObeyesdad'],exog=data['SMOKE']).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.689965
#          Iterations 3

# %%
print(model.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:             NObeyesdad   No. Observations:                 2111
# Model:                          Logit   Df Residuals:                     2110
# Method:                           MLE   Df Model:                            0
# Date:                Mon, 04 Dec 2023   Pseudo R-squ.:               7.223e-05
# Time:                        21:49:17   Log-Likelihood:                -1456.5
# converged:                       True   LL-Null:                       -1456.6
# Covariance Type:            nonrobust   LLR p-value:                       nan
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# SMOKE         -0.0805      0.022     -3.660      0.000      -0.124      -0.037
# ...

# %%
object_cols = data.drop('NObeyesdad', axis=1).select_dtypes('object').columns

# %%
for col in object_cols:
    data[col] = le.fit_transform(data[col])

# %%
data
# Out:
#       Gender        Age    Height      Weight  family_history_with_overweight  \
# 0          2  21.000000  1.620000   64.000000                               1
# 1          2  21.000000  1.520000   56.000000                               1
# 2          1  23.000000  1.800000   77.000000                               1
# 3          1  27.000000  1.800000   87.000000                               2
# 4          1  22.000000  1.780000   89.800000                               2
# ...      ...        ...       ...         ...                             ...
# 2106       2  20.976842  1.710730  131.408528                               1
# 2107       2  21.982942  1.748584  133.742943                               1
# 2108       2  22.524036  1.752206  133.689352                               1
# 2109       2  24.361936  1.739450  133.346641                               1
# 2110       2  23.664709  1.738836  133.472641                               1
#
# ...

# %%
data.corr()
# Out:
#                                   Gender       Age    Height    Weight  \
# Gender                          1.000000 -0.048394 -0.618466 -0.161668
# Age                            -0.048394  1.000000 -0.025958  0.202560
# Height                         -0.618466 -0.025958  1.000000  0.463136
# Weight                         -0.161668  0.202560  0.463136  1.000000
# family_history_with_overweight  0.102512 -0.205725 -0.247684 -0.496820
# FAVC                            0.064934 -0.063902 -0.178364 -0.272300
# FCVC                            0.274505  0.016291 -0.038121  0.216125
# NCP                            -0.067600 -0.043944  0.243672  0.107469
# CAEC                            0.006900 -0.125836 -0.133042 -0.325981
# SMOKE                           0.044698 -0.091987 -0.055499 -0.025746
# CH2O                           -0.107930 -0.045304  0.213376  0.200575
# SCC                            -0.102633  0.116283  0.133753  0.201906
# ...

# %%
X = data.drop('NObeyesdad', axis=1)
# Adding a constant to the independent variables

# Defining the dependent variable
y = data['NObeyesdad']

# Fitting the logistic regression model
model = sm.Logit(endog=y, exog=X).fit()

# Displaying the summary of the model
print(model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.014146
#          Iterations 16
#                            Logit Regression Results
# ...
# Dep. Variable:             NObeyesdad   No. Observations:                 2111
# Model:                          Logit   Df Residuals:                     2095
# Method:                           MLE   Df Model:                           15
# Date:                Mon, 04 Dec 2023   Pseudo R-squ.:                  0.9795
# Time:                        21:49:18   Log-Likelihood:                -29.862
# converged:                       True   LL-Null:                       -1456.6
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %%
model = sm.Logit(endog=data['NObeyesdad'],exog=data['Age']).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.692909
#          Iterations 3

# %%
print(model.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:             NObeyesdad   No. Observations:                 2111
# Model:                          Logit   Df Residuals:                     2110
# Method:                           MLE   Df Model:                            0
# Date:                Mon, 04 Dec 2023   Pseudo R-squ.:               -0.004195
# Time:                        21:49:18   Log-Likelihood:                -1462.7
# converged:                       True   LL-Null:                       -1456.6
# Covariance Type:            nonrobust   LLR p-value:                       nan
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Age           -0.0017      0.002     -1.002      0.316      -0.005       0.002
# ...

# %%
model = sm.Logit(endog=data['NObeyesdad'],exog=data['Weight']).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.681335
#          Iterations 4

# %%
print(model.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:             NObeyesdad   No. Observations:                 2111
# Model:                          Logit   Df Residuals:                     2110
# Method:                           MLE   Df Model:                            0
# Date:                Mon, 04 Dec 2023   Pseudo R-squ.:                 0.01258
# Time:                        21:49:18   Log-Likelihood:                -1438.3
# converged:                       True   LL-Null:                       -1456.6
# Covariance Type:            nonrobust   LLR p-value:                       nan
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Weight         0.0034      0.000      7.006      0.000       0.002       0.004
# ...

# %%
model = sm.Logit(endog=data['NObeyesdad'],exog=data['NCP']).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.690985
#          Iterations 3

# %%
print(model.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:             NObeyesdad   No. Observations:                 2111
# Model:                          Logit   Df Residuals:                     2110
# Method:                           MLE   Df Model:                            0
# Date:                Mon, 04 Dec 2023   Pseudo R-squ.:               -0.001407
# Time:                        21:49:18   Log-Likelihood:                -1458.7
# converged:                       True   LL-Null:                       -1456.6
# Covariance Type:            nonrobust   LLR p-value:                       nan
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# NCP           -0.0471      0.016     -3.017      0.003      -0.078      -0.017
# ...

# %%
sns.regplot(data=data,x='NObeyesdad',y='NCP')
# Out:
# <Axes: xlabel='NObeyesdad', ylabel='NCP'>

# %%
import matplotlib.pyplot as plt
import pandas as pd

gender_vs_obesity = data[['Gender', 'NObeyesdad']]

# Group the data by 'Gender' and count the occurrences of each obesity level
gender_obesity_counts = gender_vs_obesity.groupby(['Gender', 'NObeyesdad']).size().unstack(fill_value=0)

# Plotting the bar chart
ax = gender_obesity_counts.plot(kind='bar', figsize=(10, 6), width=0.8)

# Adding labels and title
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender vs. Obesity')

# Adding a legend
plt.legend(title='Obesity Level', loc='upper right')

# Show the plot
plt.show()

# %%
import pandas as pd
import statsmodels.api as sm

# Load your dataset here
# data = pd.read_csv('path_to_your_dataset.csv')

# Assuming you have columns named 'NCP' and 'NObeyesdad'
# Replace these with the actual column names in your dataset
X = data['NCP']  # Independent variable (Number of main meals)
y = data['NObeyesdad']  # Dependent variable (Obesity levels)

# Add a constant (intercept) to the independent variable
X = sm.add_constant(X)

# Create and fit the regression model
model = sm.OLS(y, X).fit()

# Get the summary of the regression analysis
summary = model.summary()

# Extract the p-value for the coefficient of NCP
p_value_ncp = model.pvalues['NCP']

# Define your significance level (alpha)
alpha = 0.05

# Check if the p-value is less than alpha to determine significance
if p_value_ncp < alpha:
    print("Null Hypothesis (H0) is rejected: There is a significant difference in obesity levels based on the number of main meals consumed.")
else:
    print("Null Hypothesis (H0) is not rejected: There is no significant difference in obesity levels based on the number of main meals consumed.")

# Print the summary of the regression analysis
print(summary)
# Out:
# Null Hypothesis (H0) is not rejected: There is no significant difference in obesity levels based on the number of main meals consumed.
#                             OLS Regression Results
# ...
# Dep. Variable:             NObeyesdad   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.892
# Date:                Mon, 04 Dec 2023   Prob (F-statistic):             0.0892
# Time:                        21:49:19   Log-Likelihood:                -1524.1
# No. Observations:                2111   AIC:                             3052.
# Df Residuals:                    2109   BIC:                             3063.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
